# %% [markdown]
# <a href="https://colab.research.google.com/github/game-addicted-man/2025DLP/blob/main/%EB%94%A5%EB%9F%AC%EB%8B%9D%EC%8B%A4%EC%8A%B5_Intro_to_Gymnasium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_12_01_ai_gym.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # T81-558: Applications of Deep Neural Networks
# **Module 12: Reinforcement Learning**
# * Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Washington University in St. Louis](https://engineering.wustl.edu/Programs/Pages/default.aspx)
# * For more information visit the [class website](https://sites.wustl.edu/jeffheaton/t81-558/).
# * Modified by uramoon@kw.ac.kr

# %% [markdown]
# # Module 12 Video Material
#
# * **Part 12.1: Introduction to the OpenAI Gym** [[Video]](https://www.youtube.com/watch?v=_KbUxgyisjM&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_12_01_ai_gym.ipynb)
# * Part 12.2: Introduction to Q-Learning [[Video]](https://www.youtube.com/watch?v=A3sYFcJY3lA&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_12_02_qlearningreinforcement.ipynb)
# * Part 12.3: Keras Q-Learning in the OpenAI Gym [[Video]](https://www.youtube.com/watch?v=qy1SJmsRhvM&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_12_03_keras_reinforce.ipynb)
# * Part 12.4: Atari Games with Keras Neural Networks [[Video]](https://www.youtube.com/watch?v=co0SwPWoZh0&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_12_04_atari.ipynb)
# * Part 12.5: Application of Reinforcement Learning [[Video]](https://www.youtube.com/watch?v=1jQPP3RfwMI&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_12_05_apply_rl.ipynb)

# %% [markdown]
# # Part 12.1: Introduction to the Gymnasium
#
# Gymnasium은 강화학습을 위해 만든 API입니다.
#
# ## Gymnasium Leaderboard
#
# * [Gymnasium Leaderboard](https://github.com/openai/gym/wiki/Leaderboard)
#
# You must provide a write-up with sufficient instructions to reproduce your result if you submit a score. A video of your results is suggested but not required.
#
# ## Looking at Gymnasium Environments
#
# Gymnasium은 강화학습을 수행할 수 있는 환경을 제공합니다.
# The centerpiece of Gym is the environment, which defines the "game" in which your reinforcement algorithm will compete. An environment does not need to be a game; however, it describes the following game-like features:
# * **action space**: 매 스텝에서 취할 수 있는 행동 목록 제공
# * **observation space**: 현재 관측 가능한 상태 제공
#
# Before we begin to look at Gym, it is essential to understand some of the terminology used by this library.
#
# * **Agent** - 매 스텝 행동을 취하는 기계 학습 프로그램, 행동에 따라 다음 상태가 달라집니다.
# * **Episode** - 연속된 스텝들의 모음. 에이전트가 실패하거나 미리 정해놓은 최대 스텝에 도달하면 에피소드는 종료합니다.
# * **Render** - Gymnasium은 frame단위로 에피소드에서 발생한 일들을 그릴 수 있습니다.
# * **Reward** - 에피소드가 끝날 때 행동에 따라 에이전트는 보상을 받을 수 있습니다.
# * **Non-deterministic** - 어떤 환경에서는 보상이 확률적으로 주어집니다. 예) 복권
#
# It is important to note that many gym environments specify that they are not non-deterministic even though they use random numbers to process actions. Based on the gym GitHub issue tracker, a non-deterministic property means a deterministic environment behaves randomly. Even when you give the environment a consistent seed value, this behavior is confirmed. The program can use the seed method of an environment to seed the random number generator for the environment.
#
# The Gym library allows us to query some of these attributes from environments. I created the following function to query gym environments.

# %%
# 현재 버전은 Colab에서 문제가 있어 구버전 설치
# !pip install gym==0.17.3
# !pip install pyglet==1.5.11
# Out:
# Collecting gym==0.17.3
#   Downloading gym-0.17.3.tar.gz (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 25.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.15.3)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (2.0.2)
# Collecting pyglet<=1.5.0,>=1.4.0 (from gym==0.17.3)
#   Downloading pyglet-1.5.0-py2.py3-none-any.whl.metadata (7.6 kB)
# Collecting cloudpickle<1.7.0,>=1.2.0 (from gym==0.17.3)
#   Downloading cloudpickle-1.6.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym==0.17.3) (1.0.0)
# Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Downloading pyglet-1.5.0-py2.py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 27.2 MB/s eta 0:00:00
# Building wheels for collected packages: gym
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.17.3-py3-none-any.whl size=1654617 sha256=d6d852b2efa53ac54d0a634a54d739ff3989e7e47655ae1df97c021e51e08f3d
#   Stored in directory: /root/.cache/pip/wheels/07/8b/b7/570cb90b10f17e85ccb291ba1f04af41ec697745104a2263eb
# Successfully built gym
# Installing collected packages: pyglet, cloudpickle, gym
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 3.1.1
#     Uninstalling cloudpickle-3.1.1:
#       Successfully uninstalled cloudpickle-3.1.1
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# distributed 2024.12.1 requires cloudpickle>=3.0.0, but you have cloudpickle 1.6.0 which is incompatible.
# dask 2024.12.1 requires cloudpickle>=3.0.0, but you have cloudpickle 1.6.0 which is incompatible.
# bigframes 2.4.0 requires cloudpickle>=2.0.0, but you have cloudpickle 1.6.0 which is incompatible.
# Successfully installed cloudpickle-1.6.0 gym-0.17.3 pyglet-1.5.0
# Collecting pyglet==1.5.11
#   Downloading pyglet-1.5.11-py3-none-any.whl.metadata (7.6 kB)
# Downloading pyglet-1.5.11-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.0 MB/s eta 0:00:00
# Installing collected packages: pyglet
#   Attempting uninstall: pyglet
#     Found existing installation: pyglet 1.5.0
#     Uninstalling pyglet-1.5.0:
#       Successfully uninstalled pyglet-1.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gym 0.17.3 requires pyglet<=1.5.0,>=1.4.0, but you have pyglet 1.5.11 which is incompatible.
# Successfully installed pyglet-1.5.11

# %%
import gym

# name에 해당하는 환경의 정보를 출력해주는 함수
def query_environment(name):
    env = gym.make(name)
    spec = gym.spec(name)
    print(f"Action Space: {env.action_space}")
    print(f"Observation Space: {env.observation_space}")
    print(f"Max Episode Steps: {spec.max_episode_steps}")
    print(f"Nondeterministic: {spec.nondeterministic}")
    print(f"Reward Range: {env.reward_range}")
    print(f"Reward Threshold: {spec.reward_threshold}")

# %% [markdown]
# ## MountainCar 환경 살펴보기
# We will look at the **MountainCar-v0** environment, which challenges an underpowered car to escape the valley between two mountains.  The following code describes the Mountian Car environment.
#
# <img src='https://gymnasium.farama.org/_images/mountain_car.gif' width="360">

# %%
query_environment("MountainCar-v0")
# Out:
# Action Space: Discrete(3)
# Observation Space: Box(-1.2000000476837158, 0.6000000238418579, (2,), float32)
# Max Episode Steps: 200
# Nondeterministic: False
# Reward Range: (-inf, inf)
# Reward Threshold: -110.0

# %% [markdown]
# ### TODO: MountainCar 질문에 대한 답 작성
# Hint: https://gymnasium.farama.org/environments/classic_control/mountain_car/

# %%
# Q: MountainCar-v0에서는 매 스텝 어떤 행동을 취할 수 있을까요? 각 행동의 의미를 기재하세요.
# A: 0:좌측으로 가속 , 1:아무 힘을 주지 않음 , 2:우측으로 가속

# Q: 관측할 수 있는 것은 실수 두 개인데 각 실수는 무엇을 의미할까요?
# A: 첫 번째 실수: 자동차의 위치 , 두 번째 실수: 자동차의 속도

# Q: 강화학습의 목표는 최대한 많은 리워드를 받는 것입니다.
# 이 환경에서는 골인 지점에 있지 않으면 매 스텝 -1의 리워드가 주어지는데 어떻게 행동해야 할까요?
# A: 자동차에 가속도가 붙어 골인 지점에 도달하게 해야 하기에, 왼쪽으로 가속, 오른쪽으로 가속을 반복시켜서 축적된 가속과 반동을 사용하여 올라가야 합니다.

# %% [markdown]
# ## CartPole 환경 살펴보기
# <img src="https://gymnasium.farama.org/_images/cart_pole.gif" width="360">

# %%
query_environment("CartPole-v1")
# Out:
# Action Space: Discrete(2)
# Observation Space: Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)
# Max Episode Steps: 500
# Nondeterministic: False
# Reward Range: (-inf, inf)
# Reward Threshold: 475.0

# %% [markdown]
# ## TODO: CartPole 질문에 대한 답 작성
# Hint: https://gymnasium.farama.org/environments/classic_control/cart_pole/

# %%
# Q: CartPole-v1에서는 매 스텝 어떤 행동을 취할 수 있을까요? 각 행동의 의미를 기재하세요.
# A: 0: 카트를 왼쪽으로 이동 , 1:카트를 오른쪽으로 이동

# Q: 관측할 수 있는 것은 실수 네 개인데 각 실수는 무엇을 의미할까요?
# A: 첫 번째 실수:카트의 위치 , 두 번째 실수:카트의 속도, 세 번째 실수:막대의 각도 , 네 번째 실수:막대의 각속도

# Q: Observation Space에 기재된 에피소드 종료 조건 세 가지는 무엇일까요?
# A: 첫 번째 종료조건:막대의 각도가 +-12도 이상 , 두 번째 종료조건:카트가 좌우경계를 벗어남(+-2.4) , 세 번째 종료조건:최대 타임스텝(500스텝) 초과

# Q: 강화학습의 목표는 최대한 많은 리워드를 받는 것입니다.
# 이 환경에서는 매 스텝 +1의 리워드가 주어지는데 어떻게 행동해야 할까요?
# A: 막대가 넘어지지 않도록 균형을 유지하며 오래 버티는 방향쪽으로 이동해서 최대한 많은 타임스텝동안 상태를 유지해야하는 것이 목표

# %% [markdown]
# ## Atari ROM 파일 다운로드
#
# Note: If you see a warning above, you can safely ignore it; it is a relatively minor bug in OpenAI Gym.
#
# Atari games, like breakout, can use an observation space that is either equal to the size of the Atari screen (210x160) or even use the RAM of the Atari (128 bytes) to determine the state of the game.  Yes, that's bytes, not kilobytes!

# %%
# !wget http://www.atarimania.com/roms/Roms.rar
# !unrar x -o+ /content/Roms.rar >/dev/nul
# !pip install atari_py
# !python -m atari_py.import_roms /content/ROMS >/dev/nul
# Out:
# --2025-05-30 06:20:02--  http://www.atarimania.com/roms/Roms.rar
# Resolving www.atarimania.com (www.atarimania.com)... 212.83.163.6
# Connecting to www.atarimania.com (www.atarimania.com)|212.83.163.6|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.atarimania.com/roms/Roms.rar [following]
# --2025-05-30 06:20:02--  https://www.atarimania.com/roms/Roms.rar
# Connecting to www.atarimania.com (www.atarimania.com)|212.83.163.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19612325 (19M) [application/octet-stream]
# Saving to: ‘Roms.rar’
#
# Roms.rar            100%[===================>]  18.70M  49.2MB/s    in 0.4s
#
# 2025-05-30 06:20:03 (49.2 MB/s) - ‘Roms.rar’ saved [19612325/19612325]
#
# Collecting atari_py
#   Downloading atari-py-0.2.9.tar.gz (540 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.6/540.6 kB 19.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from atari_py) (2.0.2)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from atari_py) (1.17.0)
# Building wheels for collected packages: atari_py
#   Building wheel for atari_py (setup.py) ... done
#   Created wheel for atari_py: filename=atari_py-0.2.9-cp311-cp311-linux_x86_64.whl size=2872212 sha256=0f98136815a20fed436d37c04cecd66323e7caa90ab0cdfdd443f83805836a72
#   Stored in directory: /root/.cache/pip/wheels/88/bb/c9/355a2560e9a75e6800cd54c37a19ca22badc1cf6a8b4a34c1b
# Successfully built atari_py
# Installing collected packages: atari_py
# Successfully installed atari_py-0.2.9

# %% [markdown]
# ## 두 가지 버전의 벽돌깨기 (Breakout) 게임 환경
# <img src="https://gymnasium.farama.org/v0.26.3/_images/breakout.gif" width="160"><br>
# https://gymnasium.farama.org/environments/atari/breakout/

# %%
# 인간 플레이어와 동일하게 210 x 160, 3채널 컬러 이미지를 관측하는 환경 (각 픽셀값은 0 ~ 255)
query_environment("Breakout-v0")
# Out:
# Action Space: Discrete(4)
# Observation Space: Box(0, 255, (210, 160, 3), uint8)
# Max Episode Steps: 10000
# Nondeterministic: False
# Reward Range: (-inf, inf)
# Reward Threshold: None

# %%
# Atari 게임기의 128 bytes 메모리를 관측하는 환경 (각 바이트는 0 ~ 255)
query_environment("Breakout-ram-v0")
# Out:
# Action Space: Discrete(4)
# Observation Space: Box(0, 255, (128,), uint8)
# Max Episode Steps: 10000
# Nondeterministic: False
# Reward Range: (-inf, inf)
# Reward Threshold: None

# %% [markdown]
# ## Render OpenAI Gym Environments from CoLab
#
# 그려봅시다!
#
# It is possible to visualize the game your agent is playing, even on CoLab. This section provides information on generating a video in CoLab that shows you an episode of the game your agent is playing. I based this video process on suggestions found [here](https://colab.research.google.com/drive/1flu31ulJlgiRL1dnN2ir8wGh9p7Zij2t).
#
# Begin by installing **pyvirtualdisplay** and **python-opengl**.

# %%
# 이해할 필요 없습니다.
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python3-opengl ffmpeg > /dev/null 2>&1

# %% [markdown]
# Next, we install the needed requirements to display an Atari game.

# %%
# 이해할 필요 없습니다.
# !apt-get update > /dev/null 2>&1
# !apt-get install cmake > /dev/null 2>&1
#!pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1
# !pip install gym[atari] > /dev/null 2>&1

# %% [markdown]
# Next, we define the functions used to show the video by adding it to the CoLab notebook.

# %%
# 이해할 필요 없습니다.
import gym
from gym.wrappers import Monitor
import glob
import io
import base64
from IPython.display import HTML
from pyvirtualdisplay import Display
from IPython import display as ipythondisplay

display = Display(visible=0, size=(1400, 900))
display.start()

"""
Utility functions to enable video recording of gym environment
and displaying it.
To enable video, just do "env = wrap_env(env)""
"""

def show_video():
    mp4list = glob.glob('video/*.mp4')
    if len(mp4list) > 0:
        mp4 = mp4list[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        ipythondisplay.display(HTML(data='''<video alt="test" autoplay
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
    else:
        print("Could not find video")

def wrap_env(env):
    env = Monitor(env, './video', force=True)
    return env

# %% [markdown]
# ### 아틀란티스 게임에서 랜덤 에이전트의 행동 그려보기
#
# 아틀란티스라는 게임은 플레이어가 매 스텝 다음의 행동을 취할 수 있습니다.
# 0. 아무것도 안함
# 1. 가운데 총 발사
# 2. 오른쪽 총 발사
# 3. 왼쪽 총 발사
#
# 매 번 랜덤한 행동을 취하는 에이전트의 플레이를 그려보겠습니다.

# %%
env = wrap_env(gym.make("Atlantis-v0"))
observation = env.reset()

while True:
    # 매 스텝 다음을 수행

    # 그리기
    env.render()

    # 액션 정하기
    action = env.action_space.sample()  # 랜덤하게 설정

    # 행동에 따른 새로운 관측, 리워드, 에피소드 종료 여부, 종료에 관한 정보를 반환
    observation, reward, done, info = env.step(action)

    if done:
        break

env.close()
show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ## TODO: Kung Fu Master 랜덤 에이전트 만들기
# https://gymnasium.farama.org/environments/atari/kung_fu_master/<br>
# 매 스텝 무작위 액션을 취하는 에이전트를 만들어 플레이 장면을 그려보세요.

# %%
env = wrap_env(gym.make("KungFuMaster-v4"))

#TODO
observation = env.reset()

while True:
    # 매 스텝 다음을 수행

    # 그리기
    env.render()

    # 액션 정하기 (랜덤)
    action = env.action_space.sample()

    # 행동에 따른 관측, 리워드, 종료 여부 등 반환
    observation, reward, done, info = env.step(action)

    if done:
        break

env.close()
show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ## TODO: 직접 CartPole 에이전트 만들기
# https://gymnasium.farama.org/environments/classic_control/cart_pole/
# <br>
# 단순 프로그래밍으로 200 스텝까지 살아남는 에이전트를 만들어보세요.
#
# 200 스텝 이전에 끝났다면 위에서 작성한 CartPole 문제에 대한 대답을 참고하여 <br>더 오랜 시간 살아남을 수 있도록 만들어 보세요.
#
# 원래 목표는 500 스텝이었습니다 :)

# %%
env = wrap_env(gym.make("CartPole-v1"))
observation = env.reset()

i = 0
done = False
while not done:
    i += 1

    angle = observation[2]
    angle_velocity = observation[3]

    if angle + 0.1 * angle_velocity < 0:
        action = 0
    else:
        action = 1

    observation, reward, done, info = env.step(action)
    print(f"Step {i}: action={action}, angle={angle:.4f}, angle_velocity={angle_velocity:.4f}, reward={reward}")

    env.render()

env.close()
show_video()
# Out:
# Step 1: action=1, angle=0.0404, angle_velocity=-0.0013, reward=1.0
# Step 2: action=1, angle=0.0403, angle_velocity=-0.2810, reward=1.0
# Step 3: action=0, angle=0.0347, angle_velocity=-0.5607, reward=1.0
# Step 4: action=0, angle=0.0235, angle_velocity=-0.2572, reward=1.0
# Step 5: action=1, angle=0.0183, angle_velocity=0.0428, reward=1.0
# Step 6: action=0, angle=0.0192, angle_velocity=-0.2441, reward=1.0
# Step 7: action=1, angle=0.0143, angle_velocity=0.0546, reward=1.0
# Step 8: action=0, angle=0.0154, angle_velocity=-0.2335, reward=1.0
# Step 9: action=1, angle=0.0107, angle_velocity=0.0640, reward=1.0
# Step 10: action=0, angle=0.0120, angle_velocity=-0.2253, reward=1.0
# Step 11: action=1, angle=0.0075, angle_velocity=0.0711, reward=1.0
# Step 12: action=0, angle=0.0089, angle_velocity=-0.2192, reward=1.0
# Step 13: action=1, angle=0.0046, angle_velocity=0.0763, reward=1.0
# Step 14: action=0, angle=0.0061, angle_velocity=-0.2149, reward=1.0
# Step 15: action=1, angle=0.0018, angle_velocity=0.0797, reward=1.0
# Step 16: action=0, angle=0.0034, angle_velocity=-0.2124, reward=1.0
# Step 17: action=1, angle=-0.0009, angle_velocity=0.0813, reward=1.0
# Step 18: action=0, angle=0.0008, angle_velocity=-0.2116, reward=1.0
# Step 19: action=1, angle=-0.0035, angle_velocity=0.0813, reward=1.0
# Step 20: action=0, angle=-0.0019, angle_velocity=-0.2125, reward=1.0
# Step 21: action=1, angle=-0.0061, angle_velocity=0.0796, reward=1.0
# Step 22: action=0, angle=-0.0045, angle_velocity=-0.2150, reward=1.0
# Step 23: action=0, angle=-0.0088, angle_velocity=0.0763, reward=1.0
# Step 24: action=1, angle=-0.0073, angle_velocity=0.3661, reward=1.0
# Step 25: action=1, angle=0.0000, angle_velocity=0.0712, reward=1.0
# Step 26: action=0, angle=0.0015, angle_velocity=-0.2215, reward=1.0
# Step 27: action=1, angle=-0.0030, angle_velocity=0.0716, reward=1.0
# Step 28: action=0, angle=-0.0015, angle_velocity=-0.2220, reward=1.0
# Step 29: action=1, angle=-0.0060, angle_velocity=0.0702, reward=1.0
# Step 30: action=0, angle=-0.0046, angle_velocity=-0.2243, reward=1.0
# Step 31: action=0, angle=-0.0091, angle_velocity=0.0669, reward=1.0
# Step 32: action=1, angle=-0.0077, angle_velocity=0.3567, reward=1.0
# Step 33: action=1, angle=-0.0006, angle_velocity=0.0616, reward=1.0
# Step 34: action=0, angle=0.0006, angle_velocity=-0.2313, reward=1.0
# Step 35: action=1, angle=-0.0040, angle_velocity=0.0616, reward=1.0
# Step 36: action=0, angle=-0.0027, angle_velocity=-0.2323, reward=1.0
# Step 37: action=0, angle=-0.0074, angle_velocity=0.0595, reward=1.0
# Step 38: action=1, angle=-0.0062, angle_velocity=0.3498, reward=1.0
# Step 39: action=1, angle=0.0008, angle_velocity=0.0552, reward=1.0
# Step 40: action=0, angle=0.0019, angle_velocity=-0.2372, reward=1.0
# Step 41: action=1, angle=-0.0028, angle_velocity=0.0561, reward=1.0
# Step 42: action=0, angle=-0.0017, angle_velocity=-0.2375, reward=1.0
# Step 43: action=0, angle=-0.0065, angle_velocity=0.0546, reward=1.0
# Step 44: action=1, angle=-0.0054, angle_velocity=0.3452, reward=1.0
# Step 45: action=1, angle=0.0015, angle_velocity=0.0509, reward=1.0
# Step 46: action=0, angle=0.0025, angle_velocity=-0.2413, reward=1.0
# Step 47: action=1, angle=-0.0023, angle_velocity=0.0522, reward=1.0
# Step 48: action=0, angle=-0.0012, angle_velocity=-0.2413, reward=1.0
# Step 49: action=0, angle=-0.0061, angle_velocity=0.0510, reward=1.0
# Step 50: action=1, angle=-0.0050, angle_velocity=0.3418, reward=1.0
# Step 51: action=1, angle=0.0018, angle_velocity=0.0475, reward=1.0
# Step 52: action=0, angle=0.0027, angle_velocity=-0.2446, reward=1.0
# Step 53: action=1, angle=-0.0022, angle_velocity=0.0490, reward=1.0
# Step 54: action=0, angle=-0.0012, angle_velocity=-0.2444, reward=1.0
# Step 55: action=0, angle=-0.0061, angle_velocity=0.0479, reward=1.0
# Step 56: action=1, angle=-0.0051, angle_velocity=0.3387, reward=1.0
# Step 57: action=1, angle=0.0017, angle_velocity=0.0444, reward=1.0
# Step 58: action=0, angle=0.0026, angle_velocity=-0.2478, reward=1.0
# Step 59: action=1, angle=-0.0024, angle_velocity=0.0457, reward=1.0
# Step 60: action=0, angle=-0.0015, angle_velocity=-0.2477, reward=1.0
# Step 61: action=0, angle=-0.0064, angle_velocity=0.0445, reward=1.0
# Step 62: action=1, angle=-0.0055, angle_velocity=0.3351, reward=1.0
# Step 63: action=1, angle=0.0012, angle_velocity=0.0407, reward=1.0
# Step 64: action=0, angle=0.0020, angle_velocity=-0.2516, reward=1.0
# Step 65: action=1, angle=-0.0031, angle_velocity=0.0417, reward=1.0
# Step 66: action=0, angle=-0.0022, angle_velocity=-0.2520, reward=1.0
# Step 67: action=0, angle=-0.0073, angle_velocity=0.0400, reward=1.0
# Step 68: action=1, angle=-0.0065, angle_velocity=0.3304, reward=1.0
# Step 69: action=1, angle=0.0001, angle_velocity=0.0357, reward=1.0
# Step 70: action=0, angle=0.0009, angle_velocity=-0.2570, reward=1.0
# Step 71: action=0, angle=-0.0043, angle_velocity=0.0360, reward=1.0
# Step 72: action=1, angle=-0.0036, angle_velocity=0.3273, reward=1.0
# Step 73: action=1, angle=0.0030, angle_velocity=0.0335, reward=1.0
# Step 74: action=0, angle=0.0036, angle_velocity=-0.2582, reward=1.0
# Step 75: action=1, angle=-0.0015, angle_velocity=0.0356, reward=1.0
# Step 76: action=0, angle=-0.0008, angle_velocity=-0.2576, reward=1.0
# Step 77: action=0, angle=-0.0060, angle_velocity=0.0349, reward=1.0
# Step 78: action=1, angle=-0.0053, angle_velocity=0.3257, reward=1.0
# Step 79: action=1, angle=0.0013, angle_velocity=0.0313, reward=1.0
# Step 80: action=0, angle=0.0019, angle_velocity=-0.2609, reward=1.0
# Step 81: action=0, angle=-0.0033, angle_velocity=0.0323, reward=1.0
# Step 82: action=1, angle=-0.0027, angle_velocity=0.3240, reward=1.0
# Step 83: action=1, angle=0.0038, angle_velocity=0.0304, reward=1.0
# Step 84: action=0, angle=0.0044, angle_velocity=-0.2611, reward=1.0
# Step 85: action=1, angle=-0.0008, angle_velocity=0.0330, reward=1.0
# Step 86: action=0, angle=-0.0002, angle_velocity=-0.2599, reward=1.0
# Step 87: action=0, angle=-0.0054, angle_velocity=0.0327, reward=1.0
# Step 88: action=1, angle=-0.0047, angle_velocity=0.3237, reward=1.0
# Step 89: action=1, angle=0.0018, angle_velocity=0.0295, reward=1.0
# Step 90: action=0, angle=0.0024, angle_velocity=-0.2626, reward=1.0
# Step 91: action=1, angle=-0.0029, angle_velocity=0.0308, reward=1.0
# Step 92: action=0, angle=-0.0023, angle_velocity=-0.2628, reward=1.0
# Step 93: action=0, angle=-0.0075, angle_velocity=0.0292, reward=1.0
# Step 94: action=1, angle=-0.0070, angle_velocity=0.3195, reward=1.0
# Step 95: action=1, angle=-0.0006, angle_velocity=0.0246, reward=1.0
# Step 96: action=0, angle=-0.0001, angle_velocity=-0.2682, reward=1.0
# Step 97: action=0, angle=-0.0054, angle_velocity=0.0244, reward=1.0
# Step 98: action=1, angle=-0.0049, angle_velocity=0.3154, reward=1.0
# Step 99: action=1, angle=0.0014, angle_velocity=0.0211, reward=1.0
# Step 100: action=0, angle=0.0018, angle_velocity=-0.2711, reward=1.0
# Step 101: action=0, angle=-0.0036, angle_velocity=0.0221, reward=1.0
# Step 102: action=1, angle=-0.0032, angle_velocity=0.3137, reward=1.0
# Step 103: action=1, angle=0.0031, angle_velocity=0.0200, reward=1.0
# Step 104: action=0, angle=0.0035, angle_velocity=-0.2717, reward=1.0
# Step 105: action=1, angle=-0.0020, angle_velocity=0.0221, reward=1.0
# Step 106: action=0, angle=-0.0015, angle_velocity=-0.2712, reward=1.0
# Step 107: action=0, angle=-0.0069, angle_velocity=0.0210, reward=1.0
# Step 108: action=1, angle=-0.0065, angle_velocity=0.3114, reward=1.0
# Step 109: action=1, angle=-0.0003, angle_velocity=0.0167, reward=1.0
# Step 110: action=0, angle=0.0000, angle_velocity=-0.2761, reward=1.0
# Step 111: action=0, angle=-0.0055, angle_velocity=0.0166, reward=1.0
# Step 112: action=1, angle=-0.0051, angle_velocity=0.3076, reward=1.0
# Step 113: action=1, angle=0.0010, angle_velocity=0.0133, reward=1.0
# Step 114: action=0, angle=0.0013, angle_velocity=-0.2791, reward=1.0
# Step 115: action=0, angle=-0.0043, angle_velocity=0.0140, reward=1.0
# Step 116: action=1, angle=-0.0040, angle_velocity=0.3053, reward=1.0
# Step 117: action=1, angle=0.0021, angle_velocity=0.0114, reward=1.0
# Step 118: action=0, angle=0.0023, angle_velocity=-0.2807, reward=1.0
# Step 119: action=0, angle=-0.0033, angle_velocity=0.0127, reward=1.0
# Step 120: action=1, angle=-0.0031, angle_velocity=0.3044, reward=1.0
# Step 121: action=1, angle=0.0030, angle_velocity=0.0107, reward=1.0
# Step 122: action=0, angle=0.0032, angle_velocity=-0.2810, reward=1.0
# Step 123: action=0, angle=-0.0024, angle_velocity=0.0127, reward=1.0
# Step 124: action=1, angle=-0.0021, angle_velocity=0.3047, reward=1.0
# Step 125: action=1, angle=0.0040, angle_velocity=0.0113, reward=1.0
# Step 126: action=0, angle=0.0042, angle_velocity=-0.2801, reward=1.0
# Step 127: action=0, angle=-0.0014, angle_velocity=0.0139, reward=1.0
# Step 128: action=1, angle=-0.0011, angle_velocity=0.3061, reward=1.0
# Step 129: action=1, angle=0.0050, angle_velocity=0.0131, reward=1.0
# Step 130: action=0, angle=0.0053, angle_velocity=-0.2780, reward=1.0
# Step 131: action=1, angle=-0.0003, angle_velocity=0.0163, reward=1.0
# Step 132: action=0, angle=0.0000, angle_velocity=-0.2765, reward=1.0
# Step 133: action=0, angle=-0.0055, angle_velocity=0.0162, reward=1.0
# Step 134: action=1, angle=-0.0052, angle_velocity=0.3072, reward=1.0
# Step 135: action=1, angle=0.0010, angle_velocity=0.0129, reward=1.0
# Step 136: action=0, angle=0.0012, angle_velocity=-0.2795, reward=1.0
# Step 137: action=0, angle=-0.0044, angle_velocity=0.0136, reward=1.0
# Step 138: action=1, angle=-0.0041, angle_velocity=0.3049, reward=1.0
# Step 139: action=1, angle=0.0020, angle_velocity=0.0109, reward=1.0
# Step 140: action=0, angle=0.0022, angle_velocity=-0.2812, reward=1.0
# Step 141: action=0, angle=-0.0034, angle_velocity=0.0122, reward=1.0
# Step 142: action=1, angle=-0.0032, angle_velocity=0.3038, reward=1.0
# Step 143: action=1, angle=0.0029, angle_velocity=0.0101, reward=1.0
# Step 144: action=0, angle=0.0031, angle_velocity=-0.2816, reward=1.0
# Step 145: action=0, angle=-0.0025, angle_velocity=0.0120, reward=1.0
# Step 146: action=1, angle=-0.0023, angle_velocity=0.3039, reward=1.0
# Step 147: action=1, angle=0.0038, angle_velocity=0.0105, reward=1.0
# Step 148: action=0, angle=0.0040, angle_velocity=-0.2809, reward=1.0
# Step 149: action=0, angle=-0.0016, angle_velocity=0.0130, reward=1.0
# Step 150: action=1, angle=-0.0013, angle_velocity=0.3052, reward=1.0
# Step 151: action=1, angle=0.0048, angle_velocity=0.0121, reward=1.0
# Step 152: action=0, angle=0.0050, angle_velocity=-0.2791, reward=1.0
# Step 153: action=1, angle=-0.0006, angle_velocity=0.0151, reward=1.0
# Step 154: action=0, angle=-0.0003, angle_velocity=-0.2777, reward=1.0
# Step 155: action=0, angle=-0.0058, angle_velocity=0.0149, reward=1.0
# Step 156: action=1, angle=-0.0055, angle_velocity=0.3057, reward=1.0
# Step 157: action=1, angle=0.0006, angle_velocity=0.0113, reward=1.0
# Step 158: action=0, angle=0.0008, angle_velocity=-0.2812, reward=1.0
# Step 159: action=0, angle=-0.0048, angle_velocity=0.0117, reward=1.0
# Step 160: action=1, angle=-0.0046, angle_velocity=0.3029, reward=1.0
# Step 161: action=1, angle=0.0015, angle_velocity=0.0088, reward=1.0
# Step 162: action=0, angle=0.0016, angle_velocity=-0.2835, reward=1.0
# Step 163: action=0, angle=-0.0040, angle_velocity=0.0097, reward=1.0
# Step 164: action=1, angle=-0.0038, angle_velocity=0.3012, reward=1.0
# Step 165: action=1, angle=0.0022, angle_velocity=0.0073, reward=1.0
# Step 166: action=0, angle=0.0023, angle_velocity=-0.2847, reward=1.0
# Step 167: action=0, angle=-0.0034, angle_velocity=0.0087, reward=1.0
# Step 168: action=1, angle=-0.0032, angle_velocity=0.3003, reward=1.0
# Step 169: action=1, angle=0.0028, angle_velocity=0.0066, reward=1.0
# Step 170: action=0, angle=0.0030, angle_velocity=-0.2851, reward=1.0
# Step 171: action=0, angle=-0.0027, angle_velocity=0.0085, reward=1.0
# Step 172: action=1, angle=-0.0026, angle_velocity=0.3003, reward=1.0
# Step 173: action=1, angle=0.0034, angle_velocity=0.0068, reward=1.0
# Step 174: action=0, angle=0.0036, angle_velocity=-0.2848, reward=1.0
# Step 175: action=0, angle=-0.0021, angle_velocity=0.0090, reward=1.0
# Step 176: action=1, angle=-0.0019, angle_velocity=0.3010, reward=1.0
# Step 177: action=1, angle=0.0041, angle_velocity=0.0077, reward=1.0
# Step 178: action=0, angle=0.0042, angle_velocity=-0.2837, reward=1.0
# Step 179: action=0, angle=-0.0014, angle_velocity=0.0103, reward=1.0
# Step 180: action=1, angle=-0.0012, angle_velocity=0.3026, reward=1.0
# Step 181: action=1, angle=0.0048, angle_velocity=0.0095, reward=1.0
# Step 182: action=0, angle=0.0050, angle_velocity=-0.2817, reward=1.0
# Step 183: action=1, angle=-0.0006, angle_velocity=0.0126, reward=1.0
# Step 184: action=0, angle=-0.0004, angle_velocity=-0.2803, reward=1.0
# Step 185: action=0, angle=-0.0060, angle_velocity=0.0123, reward=1.0
# Step 186: action=1, angle=-0.0057, angle_velocity=0.3031, reward=1.0
# Step 187: action=1, angle=0.0003, angle_velocity=0.0086, reward=1.0
# Step 188: action=0, angle=0.0005, angle_velocity=-0.2840, reward=1.0
# Step 189: action=0, angle=-0.0052, angle_velocity=0.0089, reward=1.0
# Step 190: action=1, angle=-0.0050, angle_velocity=0.2999, reward=1.0
# Step 191: action=1, angle=0.0010, angle_velocity=0.0056, reward=1.0
# Step 192: action=0, angle=0.0011, angle_velocity=-0.2867, reward=1.0
# Step 193: action=0, angle=-0.0046, angle_velocity=0.0063, reward=1.0
# Step 194: action=1, angle=-0.0045, angle_velocity=0.2975, reward=1.0
# Step 195: action=1, angle=0.0014, angle_velocity=0.0034, reward=1.0
# Step 196: action=0, angle=0.0015, angle_velocity=-0.2888, reward=1.0
# Step 197: action=0, angle=-0.0043, angle_velocity=0.0044, reward=1.0
# Step 198: action=1, angle=-0.0042, angle_velocity=0.2957, reward=1.0
# Step 199: action=1, angle=0.0017, angle_velocity=0.0017, reward=1.0
# Step 200: action=0, angle=0.0018, angle_velocity=-0.2904, reward=1.0
# Step 201: action=0, angle=-0.0040, angle_velocity=0.0028, reward=1.0
# Step 202: action=1, angle=-0.0040, angle_velocity=0.2942, reward=1.0
# Step 203: action=1, angle=0.0019, angle_velocity=0.0003, reward=1.0
# Step 204: action=0, angle=0.0019, angle_velocity=-0.2918, reward=1.0
# Step 205: action=0, angle=-0.0039, angle_velocity=0.0015, reward=1.0
# Step 206: action=1, angle=-0.0039, angle_velocity=0.2929, reward=1.0
# Step 207: action=1, angle=0.0020, angle_velocity=-0.0010, reward=1.0
# Step 208: action=0, angle=0.0019, angle_velocity=-0.2930, reward=1.0
# Step 209: action=0, angle=-0.0039, angle_velocity=0.0003, reward=1.0
# Step 210: action=1, angle=-0.0039, angle_velocity=0.2917, reward=1.0
# Step 211: action=1, angle=0.0019, angle_velocity=-0.0022, reward=1.0
# Step 212: action=0, angle=0.0019, angle_velocity=-0.2943, reward=1.0
# Step 213: action=0, angle=-0.0040, angle_velocity=-0.0010, reward=1.0
# Step 214: action=1, angle=-0.0040, angle_velocity=0.2904, reward=1.0
# Step 215: action=1, angle=0.0018, angle_velocity=-0.0035, reward=1.0
# Step 216: action=0, angle=0.0017, angle_velocity=-0.2957, reward=1.0
# Step 217: action=0, angle=-0.0042, angle_velocity=-0.0024, reward=1.0
# Step 218: action=1, angle=-0.0042, angle_velocity=0.2889, reward=1.0
# Step 219: action=1, angle=0.0015, angle_velocity=-0.0051, reward=1.0
# Step 220: action=0, angle=0.0014, angle_velocity=-0.2973, reward=1.0
# Step 221: action=0, angle=-0.0045, angle_velocity=-0.0042, reward=1.0
# Step 222: action=1, angle=-0.0046, angle_velocity=0.2871, reward=1.0
# Step 223: action=1, angle=0.0011, angle_velocity=-0.0070, reward=1.0
# Step 224: action=0, angle=0.0010, angle_velocity=-0.2994, reward=1.0
# Step 225: action=0, angle=-0.0050, angle_velocity=-0.0064, reward=1.0
# Step 226: action=1, angle=-0.0051, angle_velocity=0.2847, reward=1.0
# Step 227: action=0, angle=0.0006, angle_velocity=-0.0096, reward=1.0
# Step 228: action=1, angle=0.0004, angle_velocity=0.2833, reward=1.0
# Step 229: action=1, angle=0.0061, angle_velocity=-0.0093, reward=1.0
# Step 230: action=0, angle=0.0059, angle_velocity=-0.3000, reward=1.0
# Step 231: action=0, angle=-0.0001, angle_velocity=-0.0055, reward=1.0
# Step 232: action=1, angle=-0.0002, angle_velocity=0.2871, reward=1.0
# Step 233: action=1, angle=0.0055, angle_velocity=-0.0056, reward=1.0
# Step 234: action=0, angle=0.0054, angle_velocity=-0.2966, reward=1.0
# Step 235: action=0, angle=-0.0005, angle_velocity=-0.0022, reward=1.0
# Step 236: action=1, angle=-0.0006, angle_velocity=0.2903, reward=1.0
# Step 237: action=1, angle=0.0052, angle_velocity=-0.0025, reward=1.0
# Step 238: action=0, angle=0.0052, angle_velocity=-0.2936, reward=1.0
# Step 239: action=0, angle=-0.0007, angle_velocity=0.0007, reward=1.0
# Step 240: action=1, angle=-0.0007, angle_velocity=0.2932, reward=1.0
# Step 241: action=1, angle=0.0052, angle_velocity=0.0003, reward=1.0
# Step 242: action=0, angle=0.0052, angle_velocity=-0.2907, reward=1.0
# Step 243: action=0, angle=-0.0006, angle_velocity=0.0036, reward=1.0
# Step 244: action=1, angle=-0.0006, angle_velocity=0.2961, reward=1.0
# Step 245: action=1, angle=0.0054, angle_velocity=0.0032, reward=1.0
# Step 246: action=0, angle=0.0054, angle_velocity=-0.2878, reward=1.0
# Step 247: action=1, angle=-0.0003, angle_velocity=0.0066, reward=1.0
# Step 248: action=0, angle=-0.0002, angle_velocity=-0.2862, reward=1.0
# Step 249: action=0, angle=-0.0059, angle_velocity=0.0064, reward=1.0
# Step 250: action=1, angle=-0.0058, angle_velocity=0.2972, reward=1.0
# Step 251: action=1, angle=0.0002, angle_velocity=0.0027, reward=1.0
# Step 252: action=0, angle=0.0002, angle_velocity=-0.2899, reward=1.0
# Step 253: action=0, angle=-0.0056, angle_velocity=0.0029, reward=1.0
# Step 254: action=1, angle=-0.0055, angle_velocity=0.2938, reward=1.0
# Step 255: action=1, angle=0.0003, angle_velocity=-0.0006, reward=1.0
# Step 256: action=0, angle=0.0003, angle_velocity=-0.2932, reward=1.0
# Step 257: action=0, angle=-0.0055, angle_velocity=-0.0004, reward=1.0
# Step 258: action=1, angle=-0.0055, angle_velocity=0.2905, reward=1.0
# Step 259: action=0, angle=0.0003, angle_velocity=-0.0039, reward=1.0
# Step 260: action=1, angle=0.0002, angle_velocity=0.2888, reward=1.0
# Step 261: action=1, angle=0.0060, angle_velocity=-0.0038, reward=1.0
# Step 262: action=0, angle=0.0059, angle_velocity=-0.2946, reward=1.0
# Step 263: action=0, angle=-0.0000, angle_velocity=-0.0000, reward=1.0
# Step 264: action=1, angle=-0.0000, angle_velocity=0.2926, reward=1.0
# Step 265: action=1, angle=0.0058, angle_velocity=-0.0001, reward=1.0
# Step 266: action=0, angle=0.0058, angle_velocity=-0.2909, reward=1.0
# Step 267: action=1, angle=0.0000, angle_velocity=0.0036, reward=1.0
# Step 268: action=0, angle=0.0001, angle_velocity=-0.2890, reward=1.0
# Step 269: action=0, angle=-0.0057, angle_velocity=0.0037, reward=1.0
# Step 270: action=1, angle=-0.0056, angle_velocity=0.2946, reward=1.0
# Step 271: action=1, angle=0.0003, angle_velocity=0.0001, reward=1.0
# Step 272: action=0, angle=0.0003, angle_velocity=-0.2925, reward=1.0
# Step 273: action=0, angle=-0.0056, angle_velocity=0.0003, reward=1.0
# Step 274: action=1, angle=-0.0056, angle_velocity=0.2912, reward=1.0
# Step 275: action=0, angle=0.0003, angle_velocity=-0.0032, reward=1.0
# Step 276: action=1, angle=0.0002, angle_velocity=0.2896, reward=1.0
# Step 277: action=1, angle=0.0060, angle_velocity=-0.0030, reward=1.0
# Step 278: action=0, angle=0.0059, angle_velocity=-0.2938, reward=1.0
# Step 279: action=1, angle=0.0001, angle_velocity=0.0007, reward=1.0
# Step 280: action=0, angle=0.0001, angle_velocity=-0.2919, reward=1.0
# Step 281: action=0, angle=-0.0058, angle_velocity=0.0008, reward=1.0
# Step 282: action=1, angle=-0.0057, angle_velocity=0.2916, reward=1.0
# Step 283: action=0, angle=0.0001, angle_velocity=-0.0029, reward=1.0
# Step 284: action=1, angle=0.0000, angle_velocity=0.2898, reward=1.0
# Step 285: action=1, angle=0.0058, angle_velocity=-0.0028, reward=1.0
# Step 286: action=0, angle=0.0058, angle_velocity=-0.2937, reward=1.0
# Step 287: action=0, angle=-0.0001, angle_velocity=0.0008, reward=1.0
# Step 288: action=1, angle=-0.0001, angle_velocity=0.2935, reward=1.0
# Step 289: action=1, angle=0.0058, angle_velocity=0.0008, reward=1.0
# Step 290: action=0, angle=0.0058, angle_velocity=-0.2901, reward=1.0
# Step 291: action=1, angle=-0.0000, angle_velocity=0.0044, reward=1.0
# Step 292: action=0, angle=0.0001, angle_velocity=-0.2883, reward=1.0
# Step 293: action=0, angle=-0.0057, angle_velocity=0.0044, reward=1.0
# Step 294: action=1, angle=-0.0056, angle_velocity=0.2953, reward=1.0
# Step 295: action=1, angle=0.0003, angle_velocity=0.0009, reward=1.0
# Step 296: action=0, angle=0.0003, angle_velocity=-0.2917, reward=1.0
# Step 297: action=0, angle=-0.0055, angle_velocity=0.0011, reward=1.0
# Step 298: action=1, angle=-0.0055, angle_velocity=0.2920, reward=1.0
# Step 299: action=1, angle=0.0004, angle_velocity=-0.0024, reward=1.0
# Step 300: action=0, angle=0.0003, angle_velocity=-0.2950, reward=1.0
# Step 301: action=0, angle=-0.0056, angle_velocity=-0.0022, reward=1.0
# Step 302: action=1, angle=-0.0056, angle_velocity=0.2887, reward=1.0
# Step 303: action=0, angle=0.0001, angle_velocity=-0.0057, reward=1.0
# Step 304: action=1, angle=0.0000, angle_velocity=0.2870, reward=1.0
# Step 305: action=1, angle=0.0058, angle_velocity=-0.0057, reward=1.0
# Step 306: action=0, angle=0.0056, angle_velocity=-0.2965, reward=1.0
# Step 307: action=0, angle=-0.0003, angle_velocity=-0.0021, reward=1.0
# Step 308: action=1, angle=-0.0003, angle_velocity=0.2905, reward=1.0
# Step 309: action=1, angle=0.0055, angle_velocity=-0.0023, reward=1.0
# Step 310: action=0, angle=0.0054, angle_velocity=-0.2932, reward=1.0
# Step 311: action=0, angle=-0.0004, angle_velocity=0.0012, reward=1.0
# Step 312: action=1, angle=-0.0004, angle_velocity=0.2937, reward=1.0
# Step 313: action=1, angle=0.0055, angle_velocity=0.0009, reward=1.0
# Step 314: action=0, angle=0.0055, angle_velocity=-0.2900, reward=1.0
# Step 315: action=1, angle=-0.0003, angle_velocity=0.0044, reward=1.0
# Step 316: action=0, angle=-0.0002, angle_velocity=-0.2884, reward=1.0
# Step 317: action=0, angle=-0.0060, angle_velocity=0.0042, reward=1.0
# Step 318: action=1, angle=-0.0059, angle_velocity=0.2950, reward=1.0
# Step 319: action=1, angle=-0.0000, angle_velocity=0.0004, reward=1.0
# Step 320: action=0, angle=0.0000, angle_velocity=-0.2922, reward=1.0
# Step 321: action=0, angle=-0.0058, angle_velocity=0.0004, reward=1.0
# Step 322: action=1, angle=-0.0058, angle_velocity=0.2913, reward=1.0
# Step 323: action=0, angle=-0.0000, angle_velocity=-0.0032, reward=1.0
# Step 324: action=1, angle=-0.0001, angle_velocity=0.2894, reward=1.0
# Step 325: action=1, angle=0.0057, angle_velocity=-0.0033, reward=1.0
# Step 326: action=0, angle=0.0057, angle_velocity=-0.2941, reward=1.0
# Step 327: action=0, angle=-0.0002, angle_velocity=0.0003, reward=1.0
# Step 328: action=1, angle=-0.0002, angle_velocity=0.2929, reward=1.0
# Step 329: action=1, angle=0.0056, angle_velocity=0.0002, reward=1.0
# Step 330: action=0, angle=0.0056, angle_velocity=-0.2907, reward=1.0
# Step 331: action=1, angle=-0.0002, angle_velocity=0.0037, reward=1.0
# Step 332: action=0, angle=-0.0001, angle_velocity=-0.2890, reward=1.0
# Step 333: action=0, angle=-0.0059, angle_velocity=0.0036, reward=1.0
# Step 334: action=1, angle=-0.0058, angle_velocity=0.2945, reward=1.0
# Step 335: action=1, angle=0.0001, angle_velocity=-0.0000, reward=1.0
# Step 336: action=0, angle=0.0001, angle_velocity=-0.2927, reward=1.0
# Step 337: action=0, angle=-0.0058, angle_velocity=0.0000, reward=1.0
# Step 338: action=1, angle=-0.0058, angle_velocity=0.2909, reward=1.0
# Step 339: action=0, angle=0.0000, angle_velocity=-0.0036, reward=1.0
# Step 340: action=1, angle=-0.0000, angle_velocity=0.2891, reward=1.0
# Step 341: action=1, angle=0.0057, angle_velocity=-0.0036, reward=1.0
# Step 342: action=0, angle=0.0057, angle_velocity=-0.2945, reward=1.0
# Step 343: action=0, angle=-0.0002, angle_velocity=-0.0000, reward=1.0
# Step 344: action=1, angle=-0.0002, angle_velocity=0.2926, reward=1.0
# Step 345: action=1, angle=0.0056, angle_velocity=-0.0002, reward=1.0
# Step 346: action=0, angle=0.0056, angle_velocity=-0.2911, reward=1.0
# Step 347: action=1, angle=-0.0002, angle_velocity=0.0034, reward=1.0
# Step 348: action=0, angle=-0.0001, angle_velocity=-0.2894, reward=1.0
# Step 349: action=0, angle=-0.0059, angle_velocity=0.0033, reward=1.0
# Step 350: action=1, angle=-0.0058, angle_velocity=0.2941, reward=1.0
# Step 351: action=0, angle=0.0000, angle_velocity=-0.0004, reward=1.0
# Step 352: action=1, angle=0.0000, angle_velocity=0.2923, reward=1.0
# Step 353: action=1, angle=0.0059, angle_velocity=-0.0004, reward=1.0
# Step 354: action=0, angle=0.0059, angle_velocity=-0.2912, reward=1.0
# Step 355: action=1, angle=0.0000, angle_velocity=0.0033, reward=1.0
# Step 356: action=0, angle=0.0001, angle_velocity=-0.2894, reward=1.0
# Step 357: action=0, angle=-0.0057, angle_velocity=0.0033, reward=1.0
# Step 358: action=1, angle=-0.0056, angle_velocity=0.2942, reward=1.0
# Step 359: action=1, angle=0.0003, angle_velocity=-0.0002, reward=1.0
# Step 360: action=0, angle=0.0003, angle_velocity=-0.2928, reward=1.0
# Step 361: action=0, angle=-0.0056, angle_velocity=-0.0000, reward=1.0
# Step 362: action=1, angle=-0.0056, angle_velocity=0.2909, reward=1.0
# Step 363: action=0, angle=0.0002, angle_velocity=-0.0036, reward=1.0
# Step 364: action=1, angle=0.0002, angle_velocity=0.2892, reward=1.0
# Step 365: action=1, angle=0.0059, angle_velocity=-0.0034, reward=1.0
# Step 366: action=0, angle=0.0059, angle_velocity=-0.2942, reward=1.0
# Step 367: action=1, angle=-0.0000, angle_velocity=0.0003, reward=1.0
# Step 368: action=0, angle=-0.0000, angle_velocity=-0.2924, reward=1.0
# Step 369: action=0, angle=-0.0059, angle_velocity=0.0003, reward=1.0
# Step 370: action=1, angle=-0.0058, angle_velocity=0.2911, reward=1.0
# Step 371: action=0, angle=-0.0000, angle_velocity=-0.0034, reward=1.0
# Step 372: action=1, angle=-0.0001, angle_velocity=0.2893, reward=1.0
# Step 373: action=1, angle=0.0057, angle_velocity=-0.0035, reward=1.0
# Step 374: action=0, angle=0.0056, angle_velocity=-0.2943, reward=1.0
# Step 375: action=0, angle=-0.0003, angle_velocity=0.0001, reward=1.0
# Step 376: action=1, angle=-0.0003, angle_velocity=0.2927, reward=1.0
# Step 377: action=1, angle=0.0056, angle_velocity=-0.0000, reward=1.0
# Step 378: action=0, angle=0.0056, angle_velocity=-0.2910, reward=1.0
# Step 379: action=1, angle=-0.0002, angle_velocity=0.0035, reward=1.0
# Step 380: action=0, angle=-0.0002, angle_velocity=-0.2893, reward=1.0
# Step 381: action=0, angle=-0.0059, angle_velocity=0.0034, reward=1.0
# Step 382: action=1, angle=-0.0059, angle_velocity=0.2942, reward=1.0
# Step 383: action=0, angle=0.0000, angle_velocity=-0.0004, reward=1.0
# Step 384: action=1, angle=-0.0000, angle_velocity=0.2923, reward=1.0
# Step 385: action=1, angle=0.0058, angle_velocity=-0.0004, reward=1.0
# Step 386: action=0, angle=0.0058, angle_velocity=-0.2912, reward=1.0
# Step 387: action=1, angle=0.0000, angle_velocity=0.0033, reward=1.0
# Step 388: action=0, angle=0.0001, angle_velocity=-0.2894, reward=1.0
# Step 389: action=0, angle=-0.0057, angle_velocity=0.0033, reward=1.0
# Step 390: action=1, angle=-0.0056, angle_velocity=0.2942, reward=1.0
# Step 391: action=1, angle=0.0002, angle_velocity=-0.0002, reward=1.0
# Step 392: action=0, angle=0.0002, angle_velocity=-0.2928, reward=1.0
# Step 393: action=0, angle=-0.0056, angle_velocity=-0.0001, reward=1.0
# Step 394: action=1, angle=-0.0056, angle_velocity=0.2908, reward=1.0
# Step 395: action=0, angle=0.0002, angle_velocity=-0.0036, reward=1.0
# Step 396: action=1, angle=0.0001, angle_velocity=0.2891, reward=1.0
# Step 397: action=1, angle=0.0059, angle_velocity=-0.0035, reward=1.0
# Step 398: action=0, angle=0.0058, angle_velocity=-0.2943, reward=1.0
# Step 399: action=0, angle=-0.0001, angle_velocity=0.0002, reward=1.0
# Step 400: action=1, angle=-0.0000, angle_velocity=0.2928, reward=1.0
# Step 401: action=1, angle=0.0058, angle_velocity=0.0001, reward=1.0
# Step 402: action=0, angle=0.0058, angle_velocity=-0.2907, reward=1.0
# Step 403: action=1, angle=-0.0000, angle_velocity=0.0038, reward=1.0
# Step 404: action=0, angle=0.0001, angle_velocity=-0.2889, reward=1.0
# Step 405: action=0, angle=-0.0057, angle_velocity=0.0038, reward=1.0
# Step 406: action=1, angle=-0.0056, angle_velocity=0.2947, reward=1.0
# Step 407: action=1, angle=0.0003, angle_velocity=0.0003, reward=1.0
# Step 408: action=0, angle=0.0003, angle_velocity=-0.2923, reward=1.0
# Step 409: action=0, angle=-0.0056, angle_velocity=0.0004, reward=1.0
# Step 410: action=1, angle=-0.0056, angle_velocity=0.2914, reward=1.0
# Step 411: action=0, angle=0.0003, angle_velocity=-0.0031, reward=1.0
# Step 412: action=1, angle=0.0002, angle_velocity=0.2897, reward=1.0
# Step 413: action=1, angle=0.0060, angle_velocity=-0.0029, reward=1.0
# Step 414: action=0, angle=0.0059, angle_velocity=-0.2937, reward=1.0
# Step 415: action=1, angle=0.0001, angle_velocity=0.0008, reward=1.0
# Step 416: action=0, angle=0.0001, angle_velocity=-0.2918, reward=1.0
# Step 417: action=0, angle=-0.0058, angle_velocity=0.0009, reward=1.0
# Step 418: action=1, angle=-0.0057, angle_velocity=0.2917, reward=1.0
# Step 419: action=0, angle=0.0001, angle_velocity=-0.0028, reward=1.0
# Step 420: action=1, angle=0.0000, angle_velocity=0.2900, reward=1.0
# Step 421: action=1, angle=0.0058, angle_velocity=-0.0027, reward=1.0
# Step 422: action=0, angle=0.0058, angle_velocity=-0.2935, reward=1.0
# Step 423: action=1, angle=-0.0001, angle_velocity=0.0010, reward=1.0
# Step 424: action=0, angle=-0.0001, angle_velocity=-0.2918, reward=1.0
# Step 425: action=0, angle=-0.0059, angle_velocity=0.0009, reward=1.0
# Step 426: action=1, angle=-0.0059, angle_velocity=0.2917, reward=1.0
# Step 427: action=0, angle=-0.0000, angle_velocity=-0.0028, reward=1.0
# Step 428: action=1, angle=-0.0001, angle_velocity=0.2899, reward=1.0
# Step 429: action=1, angle=0.0057, angle_velocity=-0.0029, reward=1.0
# Step 430: action=0, angle=0.0056, angle_velocity=-0.2937, reward=1.0
# Step 431: action=0, angle=-0.0002, angle_velocity=0.0007, reward=1.0
# Step 432: action=1, angle=-0.0002, angle_velocity=0.2933, reward=1.0
# Step 433: action=1, angle=0.0056, angle_velocity=0.0006, reward=1.0
# Step 434: action=0, angle=0.0057, angle_velocity=-0.2903, reward=1.0
# Step 435: action=1, angle=-0.0002, angle_velocity=0.0041, reward=1.0
# Step 436: action=0, angle=-0.0001, angle_velocity=-0.2886, reward=1.0
# Step 437: action=0, angle=-0.0058, angle_velocity=0.0041, reward=1.0
# Step 438: action=1, angle=-0.0058, angle_velocity=0.2949, reward=1.0
# Step 439: action=1, angle=0.0001, angle_velocity=0.0004, reward=1.0
# Step 440: action=0, angle=0.0001, angle_velocity=-0.2922, reward=1.0
# Step 441: action=0, angle=-0.0057, angle_velocity=0.0005, reward=1.0
# Step 442: action=1, angle=-0.0057, angle_velocity=0.2914, reward=1.0
# Step 443: action=0, angle=0.0001, angle_velocity=-0.0031, reward=1.0
# Step 444: action=1, angle=0.0001, angle_velocity=0.2896, reward=1.0
# Step 445: action=1, angle=0.0059, angle_velocity=-0.0030, reward=1.0
# Step 446: action=0, angle=0.0058, angle_velocity=-0.2939, reward=1.0
# Step 447: action=0, angle=-0.0001, angle_velocity=0.0006, reward=1.0
# Step 448: action=1, angle=-0.0001, angle_velocity=0.2933, reward=1.0
# Step 449: action=1, angle=0.0058, angle_velocity=0.0006, reward=1.0
# Step 450: action=0, angle=0.0058, angle_velocity=-0.2902, reward=1.0
# Step 451: action=1, angle=0.0000, angle_velocity=0.0043, reward=1.0
# Step 452: action=0, angle=0.0001, angle_velocity=-0.2884, reward=1.0
# Step 453: action=0, angle=-0.0057, angle_velocity=0.0043, reward=1.0
# Step 454: action=1, angle=-0.0056, angle_velocity=0.2952, reward=1.0
# Step 455: action=1, angle=0.0003, angle_velocity=0.0008, reward=1.0
# Step 456: action=0, angle=0.0003, angle_velocity=-0.2918, reward=1.0
# Step 457: action=0, angle=-0.0055, angle_velocity=0.0010, reward=1.0
# Step 458: action=1, angle=-0.0055, angle_velocity=0.2919, reward=1.0
# Step 459: action=1, angle=0.0004, angle_velocity=-0.0025, reward=1.0
# Step 460: action=0, angle=0.0003, angle_velocity=-0.2951, reward=1.0
# Step 461: action=0, angle=-0.0056, angle_velocity=-0.0023, reward=1.0
# Step 462: action=1, angle=-0.0056, angle_velocity=0.2886, reward=1.0
# Step 463: action=0, angle=0.0001, angle_velocity=-0.0058, reward=1.0
# Step 464: action=1, angle=0.0000, angle_velocity=0.2869, reward=1.0
# Step 465: action=1, angle=0.0058, angle_velocity=-0.0058, reward=1.0
# Step 466: action=0, angle=0.0056, angle_velocity=-0.2967, reward=1.0
# Step 467: action=0, angle=-0.0003, angle_velocity=-0.0022, reward=1.0
# Step 468: action=1, angle=-0.0003, angle_velocity=0.2904, reward=1.0
# Step 469: action=1, angle=0.0055, angle_velocity=-0.0024, reward=1.0
# Step 470: action=0, angle=0.0054, angle_velocity=-0.2934, reward=1.0
# Step 471: action=0, angle=-0.0004, angle_velocity=0.0010, reward=1.0
# Step 472: action=1, angle=-0.0004, angle_velocity=0.2936, reward=1.0
# Step 473: action=1, angle=0.0054, angle_velocity=0.0008, reward=1.0
# Step 474: action=0, angle=0.0055, angle_velocity=-0.2902, reward=1.0
# Step 475: action=1, angle=-0.0003, angle_velocity=0.0042, reward=1.0
# Step 476: action=0, angle=-0.0003, angle_velocity=-0.2886, reward=1.0
# Step 477: action=0, angle=-0.0060, angle_velocity=0.0040, reward=1.0
# Step 478: action=1, angle=-0.0060, angle_velocity=0.2948, reward=1.0
# Step 479: action=0, angle=-0.0001, angle_velocity=0.0002, reward=1.0
# Step 480: action=1, angle=-0.0001, angle_velocity=0.2929, reward=1.0
# Step 481: action=1, angle=0.0058, angle_velocity=0.0002, reward=1.0
# Step 482: action=0, angle=0.0058, angle_velocity=-0.2907, reward=1.0
# Step 483: action=1, angle=-0.0000, angle_velocity=0.0039, reward=1.0
# Step 484: action=0, angle=0.0001, angle_velocity=-0.2888, reward=1.0
# Step 485: action=0, angle=-0.0057, angle_velocity=0.0039, reward=1.0
# Step 486: action=1, angle=-0.0056, angle_velocity=0.2948, reward=1.0
# Step 487: action=1, angle=0.0003, angle_velocity=0.0003, reward=1.0
# Step 488: action=0, angle=0.0003, angle_velocity=-0.2923, reward=1.0
# Step 489: action=0, angle=-0.0056, angle_velocity=0.0005, reward=1.0
# Step 490: action=1, angle=-0.0056, angle_velocity=0.2914, reward=1.0
# Step 491: action=0, angle=0.0003, angle_velocity=-0.0030, reward=1.0
# Step 492: action=1, angle=0.0002, angle_velocity=0.2897, reward=1.0
# Step 493: action=1, angle=0.0060, angle_velocity=-0.0029, reward=1.0
# Step 494: action=0, angle=0.0059, angle_velocity=-0.2937, reward=1.0
# Step 495: action=1, angle=0.0001, angle_velocity=0.0009, reward=1.0
# Step 496: action=0, angle=0.0001, angle_velocity=-0.2918, reward=1.0
# Step 497: action=0, angle=-0.0058, angle_velocity=0.0009, reward=1.0
# Step 498: action=1, angle=-0.0057, angle_velocity=0.2918, reward=1.0
# Step 499: action=0, angle=0.0001, angle_velocity=-0.0027, reward=1.0
# Step 500: action=1, angle=0.0000, angle_velocity=0.2900, reward=1.0
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# 사람은 Observation의 각 원소가 지니는 의미와 물리 법칙을 이용하여 코딩할 수 있지만 기계학습을 사용할 때<br>컴퓨터는 아무런 배경지식 없이 Action에 따라 Observation의 각 원소가 어떻게 변화하는지 학습합니다.
#
# 일반적인 아타리 게임에서는 딥러닝 모델이 그림을 분석하여 현재 상태에서 취할 수 있는 바람직한 액션을 선택합니다.<br>
# 수고하셨습니다.
